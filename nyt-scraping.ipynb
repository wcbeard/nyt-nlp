# %% [markdown]
# {"Title": "NYT nlp",
# "Date": "2013-7-4",
# "Category": "ipython",
# "Tags": "nlp, ipython",
# "slug": "slug-slug-slug",
# "Author": "Chris"
# }

# %% [markdown]
# This post uses the [New York Times API](http://developer.nytimes.com/docs/read/article_search_api_v2) to search for articles on US politics that include the word *scandal*, and several python libraries to grab the text of those articles and store them to MongoDB for some natural language processing analytics.

# %% [markdown]
# These commands will install some of the dependencies for this project:
#
#     pip install pymongo
#     pip install requests
#     pip install lxml
#     pip install cssselect

# %%
import requests
import json
from time import sleep
#from itertools import count
import itertools
import functools
from lxml.cssselect import CSSSelector
from lxml.html import fromstring
import pymongo
import datetime as dt
from operator import itemgetter

# %%
# %load_ext autosave
# %autosave 30
# Out:
# Usage: %autosave [seconds]
# autosaving every 30s

# %% [markdown]
# ###Mongodb

# %% [markdown]
# We need to connect to the database, assuming it's already running (`mongod` from the terminal).

# %%
connection = pymongo.Connection("localhost", 27017 )
db = connection.nyt

# %% [markdown]
# ##Get URLs

# %% [markdown]
# After using your secret API key...

# %%
from key import apikey
apiparams = {'api-key': apikey}

# %% [markdown]
# ...the first thing we need to get is the urls for all the articles that match our search criterion. This is a bit convoluted, since I couldn't find a way to search for *republican OR democrat*, so I ended up just repeating the query both times. I found out that there are lots of really interesting curated details you can use in the search, such as searching for articles pertaining to certain geographic areas, people or organizations. I used some of these features to narrow the results down to the US, restricted the dates to between 1992-2013, and just asked for title, URL and date to use as unique identifiers.

# %%
page = 0
#party = 'republican'
party = 'democrat'

q = 'http://api.nytimes.com/svc/search/v2/articlesearch?'
q = 'http://api.nytimes.com/svc/search/v2/articlesearch.json?'
params = {#'query': 'republican OR democrat AND scandal geo_facet:[UNITED STATES]',#.format(party),
          'query': 'geo_facet:[UNITED STATES]',#.format(party),
          'fq': 'republican* OR democrat* AND scandal*', # AND news_desk:("National")',
         # 'fq': 'news_desk:("National")',

 #         'query': 'body:scandal+{} geo_facet:[UNITED STATES]'.format(party),
          'fl': 'web_url,headline,pub_date,type_of_material,document_type,news_desk,keywords',
            'begin_date': '19920101',
            'end_date': '20131231',
#            'fields': 'title,url,date',
            'page': page,
            'api-key': apikey,
            'rank': 'newest',
}

# %% [markdown]
# After constructing the query, we grab the search results with [requests](http://docs.python-requests.org/en/latest/). There's no way to tell how many results there will be, so we go as long as we can, shoving everything into MongoDB, incrementing the `offset` query parameter and pausing for a break before the next page of results (the NYT has a limit on how many times you can query them per second). From the output below, we can see that there are about $49 \times 10 =490$ articles mentioning *democrat* and *scandal* under US politics (and a lot more mentioning *republican*).

# %%
page
# Out:
# 0

# %%
params
# Out:
# {'api-key': '8fab42fc6deb1a51fa79fb67781c7a3d:10:56688320',
#  'begin_date': '19920101',
#  'end_date': '20131231',
#  'fl': 'web_url,headline,pub_date,type_of_material,document_type,news_desk,keywords',
#  'fq': 'republican* OR democrat* AND scandal*',
#  'page': 0,
#  'query': 'geo_facet:[UNITED STATES]',
#  'rank': 'newest'}

# %%
import simplejson

# %%
r.url
# Out:
# u'http://api.nytimes.com/svc/search/v2/articlesearch.json?fq=republican%2A+OR+democrat%2A+AND+scandal%2A&begin_date=19920101&end_date=20131231&fields=title%2Curl%2Cdate&query=geo_facet%3A%5BUNITED+STATES%5D&fl=web_url%2Cheadline%2Cpub_date%2Ctype_of_material%2Cdocument_type%2Cnews_desk&page=0&rank=newest&api-key=8fab42fc6deb1a51fa79fb67781c7a3d%3A10%3A56688320'

# %%
def memoize(f):
    "Memoization for args and kwargs"
    @functools.wraps(f)
    def wrapper(*args, **kwargs):
        kw_tup = tuple((kargname, tuple(sorted(karg.items()))) for kargname, karg in kwargs.items())
        memo_args = args + kw_tup
        #print kwargs
        #print kw_tup
        try:
            return wrapper.cache[memo_args]
        except KeyError:
            wrapper.cache[memo_args] = res = f(*args, **kwargs)
            return res
    wrapper.cache = {}
    return wrapper

    
@memoize
def search_nyt(query, params={}):
    r = requests.get(query, params=params)
    return json.loads(r.content)

# %%
fdate = lambda d, fmt='%Y%m%d': dt.datetime.strptime(d, fmt)

for page in itertools.count():  #keep looping indefinitely
    params.update({'page': page})  #fetch another ten results from the next page
    res = search_nyt(q, params=params)["response"].copy()
#    r = requests.get(q, params=params)
#    res = json.loads(r.content)["response"]
    if res['docs']:
        for dct in res['docs']:
            dct = dct.copy()  #for memoization purposes
            url = dct.pop('web_url')
            dct['pub_date'] = fdate(dct['pub_date'].split('T')[0], '%Y-%m-%d')  #string -> format as datetime object
            dct['headline'] = dct['headline']['main']
            print dct
#            db.raw_text.update({'url': url}, {'$set': dct}, upsert=True)
    else:  #no more results
        break
    print page,
    sleep(.05)
    break
#urls = {r['url']: r for r in url_lst}    
#del url_lst
# Out:
# {u'type_of_material': u'News', u'keywords': [{u'value': u'Monks, Robert A G', u'is_major': u'N', u'rank': u'1', u'name': u'persons'}, {u'value': u'Shareholder Rights and Activism', u'is_major': u'N', u'rank': u'2', u'name': u'subject'}, {u'value': u'Mutual Funds', u'is_major': u'N', u'rank': u'4', u'name': u'subject'}], u'news_desk': u'SundayBusiness', u'headline': u'Robert A.G. Monks, Crusading Against Corporate Excess', u'document_type': u'article', u'pub_date': datetime.datetime(2013, 7, 7, 0, 0)}
# {u'type_of_material': u'News', u'keywords': [], u'news_desk': u'None', u'headline': u'Merkel Says EU Must Not Forget U.S. Spying in Push for Free Trade', u'document_type': u'article', u'pub_date': datetime.datetime(2013, 7, 6, 0, 0)}
# {u'type_of_material': u'News', u'keywords': [{u'value': u'New York City', u'is_major': u'N', u'rank': u'3', u'name': u'glocations'}, {u'value': u'Weiner, Anthony D', u'is_major': u'N', u'rank': u'1', u'name': u'persons'}, {u'value': u'Elections, Mayors', u'is_major': u'N', u'rank': u'2', u'name': u'subject'}], u'news_desk': u'Metro', u'headline': u'Weiner\u2019s Surprising Rebound From Scandal', u'document_type': u'article', u'pub_date': datetime.datetime(2013, 7, 6, 0, 0)}
# {u'type_of_material': u'News', u'keywords': [], u'news_desk': u'None', u'headline': u"Zimbabwe's Mugabe Launches 'Fight for Life' Poll Campaign", u'document_type': u'article', u'pub_date': datetime.datetime(2013, 7, 5, 0, 0)}
# {u'type_of_material': u'News', u'keywords': [], u'news_desk': u'None', u'headline': u'South American Leftist Leaders Rally for Bolivia in Snowden Saga', u'document_type': u'article', u'pub_date': datetime.datetime(2013, 7, 5, 0, 0)}
# {u'type_of_material': u'News', u'keywords': [{u'value': u'Christie, Christopher J', u'is_major': u'Y', u'rank': u'3', u'name': u'persons'}, {u'value': u'New Jersey', u'is_major': u'Y', u'rank': u'1', u'name': u'glocations'}, {u'value': u'Booker, Cory A', u'is_major': u'Y', u'rank': u'2', u'name': u'persons'}, {u'value': u'Elections, Senate', u'is_major': u'N', u'rank': u'4', u'name': u'subject'}], u'news_desk': u'Metro', u'headline': u'Booker\u2019s Opponents May Use His Friendship With Christie Against Him', u'document_type': u'article', u'pub_date': datetime.datetime(2013, 7, 5, 0, 0)}
# {u'type_of_material': u'News', u'keywords': [{u'value': u'Necas, Petr', u'is_major': u'N', u'rank': u'3', u'name': u'persons'}, {u'value': u'Czech Republic', u'is_major': u'N', u'rank': u'1', u'name': u'glocations'}, {u'value': u'Politics and Government', u'is_major': u'N', u'rank': u'2', u'name': u'subject'}, {u'value': u'Corruption (Institutional)', u'is_major': u'N', u'rank': u'4', u'name': u'subject'}], u'news_desk': u'Foreign', u'headline': u'Czech Scandal Shines Light on Corruption', u'document_type': u'article', u'pub_date': datetime.datetime(2013, 7, 5, 0, 0)}
# {u'type_of_material': u'News', u'keywords': [], u'news_desk': u'None', u'headline': u'Factbox: Main Japan Parties Ahead of July Upper House Poll', u'document_type': u'article', u'pub_date': datetime.datetime(2013, 7, 4, 0, 0)}
# {u'type_of_material': u'News', u'keywords': [], u'news_desk': u'None', u'headline': u'Illinois Ex-Governor Ryan Released After Five Years Confinement', u'document_type': u'article', u'pub_date': datetime.datetime(2013, 7, 3, 0, 0)}
# {u'type_of_material': u'News', u'keywords': [{u'value': u'Politics and Government', u'is_major': u'N', u'rank': u'4', u'name': u'subject'}, {u'value': u'Cuomo, Andrew M', u'is_major': u'N', u'rank': u'2', u'name': u'persons'}, {u'value': u'New York State', u'is_major': u'Y', u'rank': u'5', u'name': u'glocations'}, {u'value': u'Corruption (Institutional)', u'is_major': u'Y', u'rank': u'1', u'name': u'subject'}, {u'value': u'Schneiderman, Eric T', u'is_major': u'N', u'rank': u'3', u'name': u'persons'}], u'news_desk': u'Metro', u'headline': u'Cuomo Creates Special Commission to Investigate Corrupt Elected Officials ', u'document_type': u'article', u'pub_date': datetime.datetime(2013, 7, 3, 0, 0)}
# 0

# %%
res
# Out:
# {u'docs': [{u'document_type': u'article',
#    u'headline': {u'main': u'Robert A.G. Monks, Crusading Against Corporate Excess',
#     u'print_headline': u'Courtly, Yes, but Crusading Against Corporate Excess'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'persons',
#      u'rank': u'1',
#      u'value': u'Monks, Robert A G'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Shareholder Rights and Activism'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Mutual Funds'}],
#    u'news_desk': u'SundayBusiness',
#    u'pub_date': datetime.datetime(2013, 7, 7, 0, 0),
#    u'type_of_material': u'News'},
#   {u'document_type': u'article',
#    u'headline': {u'main': u'Merkel Says EU Must Not Forget U.S. Spying in Push for Free Trade',
#     u'print_headline': u'Merkel Says EU Must Not Forget U.S. Spying in Push for Free Trade'},
#    u'keywords': [],
#    u'news_desk': u'None',
#    u'pub_date': datetime.datetime(2013, 7, 6, 0, 0),
#    u'type_of_material': u'News'},
#   {u'document_type': u'article',
#    u'headline': {u'main': u'Weiner\u2019s Surprising Rebound From Scandal',
#     u'print_headline': u'Candidate\u2019s Surprising Rebound From Scandal'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'glocations',
#      u'rank': u'3',
#      u'value': u'New York City'},
#     {u'is_major': u'N',
#      u'name': u'persons',
#      u'rank': u'1',
#      u'value': u'Weiner, Anthony D'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Elections, Mayors'}],
#    u'news_desk': u'Metro',
#    u'pub_date': datetime.datetime(2013, 7, 6, 0, 0),
#    u'type_of_material': u'News'},
#   {u'document_type': u'article',
#    u'headline': {u'main': u"Zimbabwe's Mugabe Launches 'Fight for Life' Poll Campaign",
#     u'print_headline': u"Zimbabwe's Mugabe Launches 'Fight for Life' Poll Campaign"},
#    u'keywords': [],
#    u'news_desk': u'None',
#    u'pub_date': datetime.datetime(2013, 7, 5, 0, 0),
#    u'type_of_material': u'News'},
#   {u'document_type': u'article',
#    u'headline': {u'main': u'South American Leftist Leaders Rally for Bolivia in Snowden Saga',
#     u'print_headline': u'South American Leftist Leaders Rally for Bolivia in Snowden Saga'},
#    u'keywords': [],
#    u'news_desk': u'None',
#    u'pub_date': datetime.datetime(2013, 7, 5, 0, 0),
#    u'type_of_material': u'News'},
#   {u'document_type': u'article',
#    u'headline': {u'main': u'Booker\u2019s Opponents May Use His Friendship With Christie Against Him',
#     u'print_headline': u'Booker\u2019s Opponents May Use His Friendship With Christie Against Him'},
#    u'keywords': [{u'is_major': u'Y',
#      u'name': u'persons',
#      u'rank': u'3',
#      u'value': u'Christie, Christopher J'},
#     {u'is_major': u'Y',
#      u'name': u'glocations',
#      u'rank': u'1',
#      u'value': u'New Jersey'},
#     {u'is_major': u'Y',
#      u'name': u'persons',
#      u'rank': u'2',
#      u'value': u'Booker, Cory A'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Elections, Senate'}],
#    u'news_desk': u'Metro',
#    u'pub_date': datetime.datetime(2013, 7, 5, 0, 0),
#    u'type_of_material': u'News'},
#   {u'document_type': u'article',
#    u'headline': {u'main': u'Czech Scandal Shines Light on Corruption',
#     u'print_headline': u'Czech Scandal Shines Light on Corruption'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'persons',
#      u'rank': u'3',
#      u'value': u'Necas, Petr'},
#     {u'is_major': u'N',
#      u'name': u'glocations',
#      u'rank': u'1',
#      u'value': u'Czech Republic'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Politics and Government'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Corruption (Institutional)'}],
#    u'news_desk': u'Foreign',
#    u'pub_date': datetime.datetime(2013, 7, 5, 0, 0),
#    u'type_of_material': u'News'},
#   {u'document_type': u'article',
#    u'headline': {u'main': u'Factbox: Main Japan Parties Ahead of July Upper House Poll',
#     u'print_headline': u'Factbox: Main Japan Parties Ahead of July Upper House Poll'},
#    u'keywords': [],
#    u'news_desk': u'None',
#    u'pub_date': datetime.datetime(2013, 7, 4, 0, 0),
#    u'type_of_material': u'News'},
#   {u'document_type': u'article',
#    u'headline': {u'main': u'Illinois Ex-Governor Ryan Released After Five Years Confinement',
#     u'print_headline': u'Illinois Ex-Governor Ryan Released After Five Years Confinement'},
#    u'keywords': [],
#    u'news_desk': u'None',
#    u'pub_date': datetime.datetime(2013, 7, 3, 0, 0),
#    u'type_of_material': u'News'},
#   {u'document_type': u'article',
#    u'headline': {u'main': u'Cuomo Creates Special Commission to Investigate Corrupt Elected Officials ',
#     u'print_headline': u'Cuomo Creates Special Commission to Investigate Corrupt Elected Officials'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Politics and Government'},
#     {u'is_major': u'N',
#      u'name': u'persons',
#      u'rank': u'2',
#      u'value': u'Cuomo, Andrew M'},
#     {u'is_major': u'Y',
#      u'name': u'glocations',
#      u'rank': u'5',
#      u'value': u'New York State'},
#     {u'is_major': u'Y',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Corruption (Institutional)'},
#     {u'is_major': u'N',
#      u'name': u'persons',
#      u'rank': u'3',
#      u'value': u'Schneiderman, Eric T'}],
#    u'news_desk': u'Metro',
#    u'pub_date': datetime.datetime(2013, 7, 3, 0, 0),
#    u'type_of_material': u'News'}],
#  u'meta': {u'hits': 11876, u'offset': 0, u'time': 199}}

# %%
search_nyt.cache
# Out:
# {('http://api.nytimes.com/svc/search/v2/articlesearch.json?',
#   ('params',
#    (('api-key', '8fab42fc6deb1a51fa79fb67781c7a3d:10:56688320'),
#     ('begin_date', '19920101'),
#     ('end_date', '20131231'),
#     ('fl',
#      'web_url,headline,pub_date,type_of_material,document_type,news_desk,keywords'),
#     ('fq', 'republican* OR democrat* AND scandal*'),
#     ('page', 0),
#     ('query', 'geo_facet:[UNITED STATES]'),
#     ('rank',
#      'newest')))): {u'copyright': u'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#   u'response': {u'docs': [{u'document_type': u'article',
#      u'headline': {u'main': u'Robert A.G. Monks, Crusading Against Corporate Excess',
#       u'print_headline': u'Courtly, Yes, but Crusading Against Corporate Excess'},
#      u'keywords': [{u'is_major': u'N',
#        u'name': u'persons',
#        u'rank': u'1',
#        u'value': u'Monks, Robert A G'},
#       {u'is_major': u'N',
#        u'name': u'subject',
#        u'rank': u'2',
#        u'value': u'Shareholder Rights and Activism'},
#       {u'is_major': u'N',
#        u'name': u'subject',
#        u'rank': u'4',
#        u'value': u'Mutual Funds'}],
#      u'news_desk': u'SundayBusiness',
#      u'pub_date': datetime.datetime(2013, 7, 7, 0, 0),
#      u'type_of_material': u'News'},
#     {u'document_type': u'article',
#      u'headline': {u'main': u'Merkel Says EU Must Not Forget U.S. Spying in Push for Free Trade',
#       u'print_headline': u'Merkel Says EU Must Not Forget U.S. Spying in Push for Free Trade'},
#      u'keywords': [],
#      u'news_desk': u'None',
#      u'pub_date': datetime.datetime(2013, 7, 6, 0, 0),
#      u'type_of_material': u'News'},
#     {u'document_type': u'article',
#      u'headline': {u'main': u'Weiner\u2019s Surprising Rebound From Scandal',
#       u'print_headline': u'Candidate\u2019s Surprising Rebound From Scandal'},
#      u'keywords': [{u'is_major': u'N',
#        u'name': u'glocations',
#        u'rank': u'3',
#        u'value': u'New York City'},
#       {u'is_major': u'N',
#        u'name': u'persons',
#        u'rank': u'1',
#        u'value': u'Weiner, Anthony D'},
#       {u'is_major': u'N',
#        u'name': u'subject',
#        u'rank': u'2',
#        u'value': u'Elections, Mayors'}],
#      u'news_desk': u'Metro',
#      u'pub_date': datetime.datetime(2013, 7, 6, 0, 0),
#      u'type_of_material': u'News'},
#     {u'document_type': u'article',
#      u'headline': {u'main': u"Zimbabwe's Mugabe Launches 'Fight for Life' Poll Campaign",
#       u'print_headline': u"Zimbabwe's Mugabe Launches 'Fight for Life' Poll Campaign"},
#      u'keywords': [],
#      u'news_desk': u'None',
#      u'pub_date': datetime.datetime(2013, 7, 5, 0, 0),
#      u'type_of_material': u'News'},
#     {u'document_type': u'article',
#      u'headline': {u'main': u'South American Leftist Leaders Rally for Bolivia in Snowden Saga',
#       u'print_headline': u'South American Leftist Leaders Rally for Bolivia in Snowden Saga'},
#      u'keywords': [],
#      u'news_desk': u'None',
#      u'pub_date': datetime.datetime(2013, 7, 5, 0, 0),
#      u'type_of_material': u'News'},
#     {u'document_type': u'article',
#      u'headline': {u'main': u'Booker\u2019s Opponents May Use His Friendship With Christie Against Him',
#       u'print_headline': u'Booker\u2019s Opponents May Use His Friendship With Christie Against Him'},
#      u'keywords': [{u'is_major': u'Y',
#        u'name': u'persons',
#        u'rank': u'3',
#        u'value': u'Christie, Christopher J'},
#       {u'is_major': u'Y',
#        u'name': u'glocations',
#        u'rank': u'1',
#        u'value': u'New Jersey'},
#       {u'is_major': u'Y',
#        u'name': u'persons',
#        u'rank': u'2',
#        u'value': u'Booker, Cory A'},
#       {u'is_major': u'N',
#        u'name': u'subject',
#        u'rank': u'4',
#        u'value': u'Elections, Senate'}],
#      u'news_desk': u'Metro',
#      u'pub_date': datetime.datetime(2013, 7, 5, 0, 0),
#      u'type_of_material': u'News'},
#     {u'document_type': u'article',
#      u'headline': {u'main': u'Czech Scandal Shines Light on Corruption',
#       u'print_headline': u'Czech Scandal Shines Light on Corruption'},
#      u'keywords': [{u'is_major': u'N',
#        u'name': u'persons',
#        u'rank': u'3',
#        u'value': u'Necas, Petr'},
#       {u'is_major': u'N',
#        u'name': u'glocations',
#        u'rank': u'1',
#        u'value': u'Czech Republic'},
#       {u'is_major': u'N',
#        u'name': u'subject',
#        u'rank': u'2',
#        u'value': u'Politics and Government'},
#       {u'is_major': u'N',
#        u'name': u'subject',
#        u'rank': u'4',
#        u'value': u'Corruption (Institutional)'}],
#      u'news_desk': u'Foreign',
#      u'pub_date': datetime.datetime(2013, 7, 5, 0, 0),
#      u'type_of_material': u'News'},
#     {u'document_type': u'article',
#      u'headline': {u'main': u'Factbox: Main Japan Parties Ahead of July Upper House Poll',
#       u'print_headline': u'Factbox: Main Japan Parties Ahead of July Upper House Poll'},
#      u'keywords': [],
#      u'news_desk': u'None',
#      u'pub_date': datetime.datetime(2013, 7, 4, 0, 0),
#      u'type_of_material': u'News'},
#     {u'document_type': u'article',
#      u'headline': {u'main': u'Illinois Ex-Governor Ryan Released After Five Years Confinement',
#       u'print_headline': u'Illinois Ex-Governor Ryan Released After Five Years Confinement'},
#      u'keywords': [],
#      u'news_desk': u'None',
#      u'pub_date': datetime.datetime(2013, 7, 3, 0, 0),
#      u'type_of_material': u'News'},
#     {u'document_type': u'article',
#      u'headline': {u'main': u'Cuomo Creates Special Commission to Investigate Corrupt Elected Officials ',
#       u'print_headline': u'Cuomo Creates Special Commission to Investigate Corrupt Elected Officials'},
#      u'keywords': [{u'is_major': u'N',
#        u'name': u'subject',
#        u'rank': u'4',
#        u'value': u'Politics and Government'},
#       {u'is_major': u'N',
#        u'name': u'persons',
#        u'rank': u'2',
#        u'value': u'Cuomo, Andrew M'},
#       {u'is_major': u'Y',
#        u'name': u'glocations',
#        u'rank': u'5',
#        u'value': u'New York State'},
#       {u'is_major': u'Y',
#        u'name': u'subject',
#        u'rank': u'1',
#        u'value': u'Corruption (Institutional)'},
#       {u'is_major': u'N',
#        u'name': u'persons',
#        u'rank': u'3',
#        u'value': u'Schneiderman, Eric T'}],
#      u'news_desk': u'Metro',
#      u'pub_date': datetime.datetime(2013, 7, 3, 0, 0),
#      u'type_of_material': u'News'}],
#    u'meta': {u'hits': 11876, u'offset': 0, u'time': 199}},
#   u'status': u'OK'}}

# %%
dct
# Out:
# {'date': datetime.datetime(2013, 7, 3, 0, 0),
#  u'document_type': u'article',
#  u'headline': {u'main': u'Cuomo Creates Special Commission to Investigate Corrupt Elected Officials ',
#   u'print_headline': u'Cuomo Creates Special Commission to Investigate Corrupt Elected Officials'},
#  u'keywords': [{u'is_major': u'N',
#    u'name': u'subject',
#    u'rank': u'4',
#    u'value': u'Politics and Government'},
#   {u'is_major': u'N',
#    u'name': u'persons',
#    u'rank': u'2',
#    u'value': u'Cuomo, Andrew M'},
#   {u'is_major': u'Y',
#    u'name': u'glocations',
#    u'rank': u'5',
#    u'value': u'New York State'},
#   {u'is_major': u'Y',
#    u'name': u'subject',
#    u'rank': u'1',
#    u'value': u'Corruption (Institutional)'},
#   {u'is_major': u'N',
#    u'name': u'persons',
#    u'rank': u'3',
#    u'value': u'Schneiderman, Eric T'}],
#  u'news_desk': u'Metro',
#  u'pub_date': u'2013-07-03T00:00:00Z',
#  u'type_of_material': u'News'}

# %%
jj = json.loads(r.content)
jj['status']
# Out:
# u'OK'

# %%
jj
# Out:
# {u'copyright': u'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#  u'response': {u'docs': [{u'document_type': u'article',
#     u'headline': {u'main': u'Robert A.G. Monks, Crusading Against Corporate Excess',
#      u'print_headline': u'Courtly, Yes, but Crusading Against Corporate Excess'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Monks, Robert A G'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Shareholder Rights and Activism'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Mutual Funds'}],
#     u'news_desk': u'SundayBusiness',
#     u'pub_date': u'2013-07-07T00:00:00Z',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2013/07/07/business/mutfund/robert-ag-monks-crusading-against-corporate-excess.html'},
#    {u'document_type': u'article',
#     u'headline': {u'main': u'Merkel Says EU Must Not Forget U.S. Spying in Push for Free Trade',
#      u'print_headline': u'Merkel Says EU Must Not Forget U.S. Spying in Push for Free Trade'},
#     u'keywords': [],
#     u'news_desk': u'None',
#     u'pub_date': u'2013-07-06T09:58:43Z',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/reuters/2013/07/06/world/europe/06reuters-usa-security-europe-germany.html'},
#    {u'document_type': u'article',
#     u'headline': {u'main': u'Weiner\u2019s Surprising Rebound From Scandal',
#      u'print_headline': u'Candidate\u2019s Surprising Rebound From Scandal'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'3',
#       u'value': u'New York City'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Weiner, Anthony D'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Elections, Mayors'}],
#     u'news_desk': u'Metro',
#     u'pub_date': u'2013-07-06T00:00:00Z',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2013/07/06/nyregion/weiners-surprising-rebound-from-scandal.html'},
#    {u'document_type': u'article',
#     u'headline': {u'main': u"Zimbabwe's Mugabe Launches 'Fight for Life' Poll Campaign",
#      u'print_headline': u"Zimbabwe's Mugabe Launches 'Fight for Life' Poll Campaign"},
#     u'keywords': [],
#     u'news_desk': u'None',
#     u'pub_date': u'2013-07-05T12:01:00Z',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/reuters/2013/07/05/world/africa/05reuters-zimbabwe-elections.html'},
#    {u'document_type': u'article',
#     u'headline': {u'main': u'South American Leftist Leaders Rally for Bolivia in Snowden Saga',
#      u'print_headline': u'South American Leftist Leaders Rally for Bolivia in Snowden Saga'},
#     u'keywords': [],
#     u'news_desk': u'None',
#     u'pub_date': u'2013-07-05T00:08:03Z',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/reuters/2013/07/05/world/europe/05reuters-usa-security-latinamerica.html'},
#    {u'document_type': u'article',
#     u'headline': {u'main': u'Booker\u2019s Opponents May Use His Friendship With Christie Against Him',
#      u'print_headline': u'Booker\u2019s Opponents May Use His Friendship With Christie Against Him'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'3',
#       u'value': u'Christie, Christopher J'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'1',
#       u'value': u'New Jersey'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'2',
#       u'value': u'Booker, Cory A'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Elections, Senate'}],
#     u'news_desk': u'Metro',
#     u'pub_date': u'2013-07-05T00:00:00Z',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2013/07/05/nyregion/bookers-opponents-may-use-his-friendship-with-christie-against-him.html'},
#    {u'document_type': u'article',
#     u'headline': {u'main': u'Czech Scandal Shines Light on Corruption',
#      u'print_headline': u'Czech Scandal Shines Light on Corruption'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'3',
#       u'value': u'Necas, Petr'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'1',
#       u'value': u'Czech Republic'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Politics and Government'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Corruption (Institutional)'}],
#     u'news_desk': u'Foreign',
#     u'pub_date': u'2013-07-05T00:00:00Z',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2013/07/05/world/europe/czech-scandal-shines-light-on-corruption.html'},
#    {u'document_type': u'article',
#     u'headline': {u'main': u'Factbox: Main Japan Parties Ahead of July Upper House Poll',
#      u'print_headline': u'Factbox: Main Japan Parties Ahead of July Upper House Poll'},
#     u'keywords': [],
#     u'news_desk': u'None',
#     u'pub_date': u'2013-07-04T00:41:15Z',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/reuters/2013/07/04/world/asia/04reuters-japan-election-parties.html'},
#    {u'document_type': u'article',
#     u'headline': {u'main': u'Illinois Ex-Governor Ryan Released After Five Years Confinement',
#      u'print_headline': u'Illinois Ex-Governor Ryan Released After Five Years Confinement'},
#     u'keywords': [],
#     u'news_desk': u'None',
#     u'pub_date': u'2013-07-03T12:35:28Z',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/reuters/2013/07/03/us/03reuters-usa-crime-ryan.html'},
#    {u'document_type': u'article',
#     u'headline': {u'main': u'Cuomo Creates Special Commission to Investigate Corrupt Elected Officials ',
#      u'print_headline': u'Cuomo Creates Special Commission to Investigate Corrupt Elected Officials'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Politics and Government'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'2',
#       u'value': u'Cuomo, Andrew M'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'5',
#       u'value': u'New York State'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Corruption (Institutional)'},
#      {u'is_major': u'N',
#       u'name': u'persons',
#       u'rank': u'3',
#       u'value': u'Schneiderman, Eric T'}],
#     u'news_desk': u'Metro',
#     u'pub_date': u'2013-07-03T00:00:00Z',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2013/07/03/nyregion/cuomo-names-panel-to-investigate-corrupt-elected-officials.html'}],
#   u'meta': {u'hits': 11876, u'offset': 0, u'time': 67}},
#  u'status': u'OK'}

# %%
res['meta']
# Out:
# {u'hits': 11876, u'offset': 0, u'time': 86}

# %%
','.join(['web_url', 'headline', 'pub_date', 'type_of_material', 'document_type'])
# Out:
# 'web_url,headline,pub_date,type_of_material,document_type'

# %%
relevant = itemgetter('web_url', 'headline', 'pub_date', 'type_of_material', 'document_type')

# %%
rrs = itertools.imap(relevant, res['docs'])

# %%
[date for _, _, date, _, _ in rrs]
# Out:
# [u'2013-07-07T00:00:00Z',
#  u'2013-07-06T09:58:43Z',
#  u'2013-07-06T00:00:00Z',
#  u'2013-07-05T12:01:00Z',
#  u'2013-07-05T00:08:03Z',
#  u'2013-07-05T00:00:00Z',
#  u'2013-07-05T00:00:00Z',
#  u'2013-07-04T00:41:15Z',
#  u'2013-07-03T12:35:28Z',
#  u'2013-07-03T00:00:00Z']

# %%
res['docs'][0]
# Out:
# {u'_id': u'51d8a6bc7e0d9c0839d2e5b9',
#  u'abstract': None,
#  u'blog': [],
#  u'byline': {u'original': u'By ERIC LICHTBLAU',
#   u'person': [{u'firstname': u'Eric',
#     u'lastname': u'LICHTBLAU',
#     u'organization': u'',
#     u'rank': 1,
#     u'role': u'reported'}]},
#  u'document_type': u'article',
#  u'headline': {u'main': u'In Secret, Court Vastly Broadens Powers of N.S.A.',
#   u'print_headline': u'In Secret, Court Vastly Broadens Powers of N.S.A.'},
#  u'keywords': [{u'is_major': u'N',
#    u'name': u'subject',
#    u'rank': u'4',
#    u'value': u'Surveillance of Citizens by Government'},
#   {u'is_major': u'N',
#    u'name': u'organizations',
#    u'rank': u'2',
#    u'value': u'Foreign Intelligence Surveillance Court'},
#   {u'is_major': u'N',
#    u'name': u'subject',
#    u'rank': u'5',
#    u'value': u'Foreign Intelligence Surveillance Act (FISA)'},
#   {u'is_major': u'N',
#    u'name': u'organizations',
#    u'rank': u'1',
#    u'value': u'National Security Agency'},
#   {u'is_major': u'N',
#    u'name': u'subject',
#    u'rank': u'6',
#    u'value': u'United States Politics and Government'},
#   {u'is_major': u'N',
#    u'name': u'subject',
#    u'rank': u'3',
#    u'value': u'Fourth Amendment (US Constitution)'}],
#  u'lead_paragraph': u'With the secret FISA court&#8217;s approval, the National Security Agency is collecting data not only on terrorism cases but also other foreign intelligence issues like nuclear proliferation and cyberattacks.',
#  u'multimedia': [],
#  u'news_desk': u'National',
#  u'print_page': u'1',
#  u'pub_date': u'2013-07-07T00:00:00Z',
#  u'section_name': u'U.S.',
#  u'snippet': u'With the secret FISA court&#8217;s approval, the National Security Agency is collecting data not only on terrorism cases but also other foreign intelligence issues like nuclear proliferation and cyberattacks.',
#  u'source': u'The New York Times',
#  u'subsection_name': None,
#  u'type_of_material': u'News',
#  u'web_url': u'http://www.nytimes.com/2013/07/07/us/in-secret-court-vastly-broadens-powers-of-nsa.html',
#  u'word_count': u'1583'}

# %%
rr = json.loads(r.content)

# %%
rr['response']
# Out:
# {u'docs': [{u'_id': u'51d8a6bc7e0d9c0839d2e5b9',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'original': u'By ERIC LICHTBLAU',
#     u'person': [{u'firstname': u'Eric',
#       u'lastname': u'LICHTBLAU',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'main': u'In Secret, Court Vastly Broadens Powers of N.S.A.',
#     u'print_headline': u'In Secret, Court Vastly Broadens Powers of N.S.A.'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Surveillance of Citizens by Government'},
#     {u'is_major': u'N',
#      u'name': u'organizations',
#      u'rank': u'2',
#      u'value': u'Foreign Intelligence Surveillance Court'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'5',
#      u'value': u'Foreign Intelligence Surveillance Act (FISA)'},
#     {u'is_major': u'N',
#      u'name': u'organizations',
#      u'rank': u'1',
#      u'value': u'National Security Agency'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'6',
#      u'value': u'United States Politics and Government'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Fourth Amendment (US Constitution)'}],
#    u'lead_paragraph': u'With the secret FISA court&#8217;s approval, the National Security Agency is collecting data not only on terrorism cases but also other foreign intelligence issues like nuclear proliferation and cyberattacks.',
#    u'multimedia': [],
#    u'news_desk': u'National',
#    u'print_page': u'1',
#    u'pub_date': u'2013-07-07T00:00:00Z',
#    u'section_name': u'U.S.',
#    u'snippet': u'With the secret FISA court&#8217;s approval, the National Security Agency is collecting data not only on terrorism cases but also other foreign intelligence issues like nuclear proliferation and cyberattacks.',
#    u'source': u'The New York Times',
#    u'subsection_name': None,
#    u'type_of_material': u'News',
#    u'web_url': u'http://www.nytimes.com/2013/07/07/us/in-secret-court-vastly-broadens-powers-of-nsa.html',
#    u'word_count': u'1583'},
#   {u'_id': u'51d8935a7e0d9c0839d2e59e',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'original': u'By ANNE BARNARD, HWAIDA SAAD and HANIA MOURTADA',
#     u'person': [{u'firstname': u'Anne',
#       u'lastname': u'BARNARD',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'},
#      {u'firstname': u'Hwaida',
#       u'lastname': u'SAAD',
#       u'organization': u'',
#       u'rank': 2,
#       u'role': u'reported'},
#      {u'firstname': u'Hania',
#       u'lastname': u'MOURTADA',
#       u'organization': u'',
#       u'rank': 3,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'main': u'Activist Who Documented Syrian War\u2019s Toll Became Its Victim',
#     u'print_headline': u'Activist Who Documented Syrian War&#8217;s Toll Became Its Victim'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'5',
#      u'value': u'Video Recordings and Downloads'},
#     {u'is_major': u'N',
#      u'name': u'glocations',
#      u'rank': u'3',
#      u'value': u'Damascus (Syria)'},
#     {u'is_major': u'N',
#      u'name': u'organizations',
#      u'rank': u'6',
#      u'value': u'Skype Technologies'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Middle East and North Africa Unrest (2010- )'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Civilian Casualties'}],
#    u'lead_paragraph': u'A relentless chronicler of unrest, Fidaa al-Baali was among the first to show his face on camera, and his own trajectory reflected the shift in the Syrian conflict.',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2013/07/07/world/syria/syria-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/world/syria/syria-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2013/07/07/world/syria/syria-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/world/syria/syria-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'Foreign',
#    u'print_page': u'10',
#    u'pub_date': u'2013-07-07T00:00:00Z',
#    u'section_name': u'World',
#    u'snippet': u'A relentless chronicler of unrest, Fidaa al-Baali was among the first to show his face on camera, and his own trajectory reflected the shift in the Syrian conflict.',
#    u'source': u'The New York Times',
#    u'subsection_name': u'Middle East',
#    u'type_of_material': u'News',
#    u'web_url': u'http://www.nytimes.com/2013/07/07/world/middleeast/activist-who-documented-syrian-wars-toll-became-its-victim.html',
#    u'word_count': u'1056'},
#   {u'_id': u'51d8838f7e0d9c0839d2e587',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'original': u'By JORGE ARANGURE Jr',
#     u'person': [{u'firstname': u'Jorge',
#       u'lastname': u'ARANGURE',
#       u'organization': u'',
#       u'qualifier': u'Jr',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'kicker': u'Yankees 5, Orioles 4',
#     u'main': u'Yankees Rescue Uneven Pettitte for 6th Straight Win',
#     u'print_headline': u'Pettitte Is Off Against Orioles, but Yanks Still Win Their Sixth Straight '},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'persons',
#      u'rank': u'5',
#      u'value': u'Nunez, Eduardo'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Baseball'},
#     {u'is_major': u'N',
#      u'name': u'organizations',
#      u'rank': u'1',
#      u'value': u'New York Yankees'},
#     {u'is_major': u'N',
#      u'name': u'organizations',
#      u'rank': u'2',
#      u'value': u'Baltimore Orioles'},
#     {u'is_major': u'N',
#      u'name': u'persons',
#      u'rank': u'4',
#      u'value': u'Pettitte, Andy'}],
#    u'lead_paragraph': u'Andy Pettitte persevered through early trouble to pitch six and two-thirds innings, and Eduardo Nunez drove in the winning run against the Orioles after coming off the disabled list.',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2013/07/07/sports/07YANKEES/07YANKEES-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/sports/07YANKEES/07YANKEES-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 466,
#      u'legacy': {u'xlarge': u'images/2013/07/07/sports/07YANKEES/07YANKEES-articleLarge.jpg',
#       u'xlargeheight': u'466',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/sports/07YANKEES/07YANKEES-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2013/07/07/sports/07YANKEES/07YANKEES-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/sports/07YANKEES/07YANKEES-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'Sports',
#    u'print_page': u'',
#    u'pub_date': u'2013-07-07T00:00:00Z',
#    u'section_name': u'Sports',
#    u'snippet': u'Andy Pettitte persevered through early trouble to pitch six and two-thirds innings, and Eduardo Nunez drove in the winning run against the Orioles after coming off the disabled list.',
#    u'source': u'The New York Times',
#    u'subsection_name': u'Baseball',
#    u'type_of_material': u'News',
#    u'web_url': u'http://www.nytimes.com/2013/07/07/sports/baseball/yankees-rescue-an-uneven-pettitte-for-sixth-straight-victory.html',
#    u'word_count': u'863'},
#   {u'_id': u'51d87a087e0d9c0839d2e577',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'original': u'By GRETCHEN MORGENSON',
#     u'person': [{u'firstname': u'Gretchen',
#       u'lastname': u'MORGENSON',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'kicker': u'Fair Game',
#     u'main': u'New Momentum for Change in Corporate Board Elections',
#     u'print_headline': u'35 Big Steps To Accountability '},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'5',
#      u'value': u'Mutual Funds'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Shareholder Rights and Activism'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Boards of Directors'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Pensions and Retirement Plans'}],
#    u'lead_paragraph': u'The Shareholder Rights Project has had  remarkable early success in persuading companies to put directors up for re-election every year, instead of in staggered terms.',
#    u'multimedia': [{u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2010/04/19/business/morgenson/morgenson-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2010/04/19/business/morgenson/morgenson-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'SundayBusiness',
#    u'print_page': u'1',
#    u'pub_date': u'2013-07-07T00:00:00Z',
#    u'section_name': u'Business Day',
#    u'snippet': u'The Shareholder Rights Project has had  remarkable early success in persuading companies to put directors up for re-election every year, instead of in staggered terms.',
#    u'source': u'',
#    u'subsection_name': None,
#    u'type_of_material': u'News',
#    u'web_url': u'http://www.nytimes.com/2013/07/07/business/new-momentum-for-change-in-corporate-board-elections.html',
#    u'word_count': u'1031'},
#   {u'_id': u'51d86a947e0d9c0839d2e559',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'original': u'By NICHOLAS D. KRISTOF',
#     u'person': [{u'firstname': u'Nicholas',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'kicker': u'Op-Ed Columnist',
#     u'main': u'Qaeda Rebels Are Gone. Death Isn\u2019t.',
#     u'print_headline': u'Qaeda Rebels Are Gone. Death Isn&#8217;t.'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'organizations',
#      u'rank': u'5',
#      u'value': u'World Food Program'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Malnutrition'},
#     {u'is_major': u'N',
#      u'name': u'glocations',
#      u'rank': u'1',
#      u'value': u'Mali'},
#     {u'is_major': u'N', u'name': u'subject', u'rank': u'2', u'value': u'Food'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Muslims and Islam'}],
#    u'lead_paragraph': u'An Islamist coup grabbed headlines in Mali, which is the first stop on this year\u2019s win-a-trip. But the real threat to Malian children is extreme malnutrition.',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2010/09/16/opinion/Kristof_New/Kristof_New-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2010/09/16/opinion/Kristof_New/Kristof_New-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 766,
#      u'legacy': {u'xlarge': u'images/2010/09/16/opinion/Kristof_New/Kristof_New-articleLarge.jpg',
#       u'xlargeheight': u'766',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2010/09/16/opinion/Kristof_New/Kristof_New-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2010/09/16/opinion/Kristof_New/Kristof_New-thumbStandard-v3.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2010/09/16/opinion/Kristof_New/Kristof_New-thumbStandard-v3.jpg',
#      u'width': 75}],
#    u'news_desk': u'Editorial',
#    u'print_page': u'11',
#    u'pub_date': u'2013-07-07T00:00:00Z',
#    u'section_name': u'Opinion',
#    u'snippet': u'An Islamist coup grabbed headlines in Mali, which is the first stop on this year\u2019s win-a-trip. But the real threat to Malian children is extreme malnutrition.',
#    u'source': u'The New York Times',
#    u'subsection_name': u'Sunday Review',
#    u'type_of_material': u'Op-Ed',
#    u'web_url': u'http://www.nytimes.com/2013/07/07/opinion/sunday/kristof-qaeda-rebels-are-gone-death-isnt.html',
#    u'word_count': u'797'},
#   {u'_id': u'51d841b07e0d9c0839d2e503',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'original': u'By ANNE BARNARD',
#     u'person': [{u'firstname': u'Anne',
#       u'lastname': u'BARNARD',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'main': u'Trying to End Rifts, Syria Opposition in Exile Elects President',
#     u'print_headline': u'Trying to End Divisions, Syrian Opposition in Exile Elects President'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'glocations',
#      u'rank': u'1',
#      u'value': u'Syria'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Middle East and North Africa Unrest (2010- )'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Elections'}],
#    u'lead_paragraph': u'The group\u2019s new president, Ahmad Jarba, is a tribal sheik from northeastern Syria and is seen as close to the government of Saudi Arabia.',
#    u'multimedia': [],
#    u'news_desk': u'Foreign',
#    u'print_page': u'10',
#    u'pub_date': u'2013-07-07T00:00:00Z',
#    u'section_name': u'World',
#    u'snippet': u'The group\u2019s new president, Ahmad Jarba, is a tribal sheik from northeastern Syria and is seen as close to the government of Saudi Arabia.',
#    u'source': u'The New York Times',
#    u'subsection_name': u'Middle East',
#    u'type_of_material': u'News',
#    u'web_url': u'http://www.nytimes.com/2013/07/07/world/middleeast/trying-to-end-rifts-syria-opposition-in-exile-elects-president.html',
#    u'word_count': u'619'},
#   {u'_id': u'51d83feb7e0d9c0839d2e4fc',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'original': u'By JON BRAND',
#     u'person': [{u'firstname': u'Jon',
#       u'lastname': u'BRAND',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'main': u'Weighing Changes to the Business Side After Doping Scandals',
#     u'print_headline': u'Weighing Changes to the Business Side After Doping Scandals '},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Bicycles and Bicycling'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Doping (Sports)'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Tour de France (Bicycle Race)'}],
#    u'lead_paragraph': u'Calls to reform the business side of cycling have started a debate over revenue sharing, a new racing calendar and changes to the sport\u2019s governing body.',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2013/07/07/sports/cycling-skybox/cycling-skybox-thumbWide-v2.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/sports/cycling-skybox/cycling-skybox-thumbWide-v2.jpg',
#      u'width': 190},
#     {u'height': 397,
#      u'legacy': {u'xlarge': u'images/2013/07/07/sports/cycling-skybox/cycling-skybox-articleLarge-v2.jpg',
#       u'xlargeheight': u'397',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/sports/cycling-skybox/cycling-skybox-articleLarge-v2.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2013/07/07/sports/cycling-skybox/cycling-skybox-thumbStandard-v2.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/sports/cycling-skybox/cycling-skybox-thumbStandard-v2.jpg',
#      u'width': 75}],
#    u'news_desk': u'Sports',
#    u'print_page': u'9',
#    u'pub_date': u'2013-07-07T00:00:00Z',
#    u'section_name': u'Sports',
#    u'snippet': u'Calls to reform the business side of cycling have started a debate over revenue sharing, a new racing calendar and changes to the sport\u2019s governing body.',
#    u'source': u'The New York Times',
#    u'subsection_name': u'Cycling',
#    u'type_of_material': u'News',
#    u'web_url': u'http://www.nytimes.com/2013/07/07/sports/cycling/stung-by-doping-scandals-cycling-weighs-changes-to-its-business-side.html',
#    u'word_count': u'1749'},
#   {u'_id': u'51d75d967e0d9c0839d2e3e5',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': [],
#    u'document_type': u'article',
#    u'headline': {u'main': u'Events in Westchester'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Art'},
#     {u'is_major': u'N',
#      u'name': u'glocations',
#      u'rank': u'3',
#      u'value': u'Westchester County (NY)'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Culture (Arts)'}],
#    u'lead_paragraph': u'A guide to cultural and recreational events in the Hudson Valley.',
#    u'multimedia': [],
#    u'news_desk': u'Metro',
#    u'print_page': u'',
#    u'pub_date': u'2013-07-07T00:00:00Z',
#    u'section_name': u'N.Y. / Region',
#    u'snippet': u'A guide to cultural and recreational events in the Hudson Valley.',
#    u'source': u'The New York Times',
#    u'subsection_name': None,
#    u'type_of_material': u'Schedule',
#    u'web_url': u'http://www.nytimes.com/2013/07/07/nyregion/events-in-westchester.html',
#    u'word_count': u'3291'},
#   {u'_id': u'51d730237e0d9c0839d2e38c',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'original': u'By MATT HABER',
#     u'person': [{u'firstname': u'Matt',
#       u'lastname': u'HABER',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'main': u'A Trip to Camp to Break a Tech Addiction',
#     u'print_headline': u'Coming Clean at Camp '},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Computers and the Internet'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'3',
#      u'value': u'Science and Technology'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'4',
#      u'value': u'Smartphones'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Therapy and Rehabilitation'}],
#    u'lead_paragraph': u'In the woods, tech-addled adults can break the bonds of the digital world, at least temporarily,  and return to the glories of color wars and real (not Facebook) friends.',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2013/07/07/fashion/07JPCAMP3/JPCAMP3-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/fashion/07JPCAMP3/JPCAMP3-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 901,
#      u'legacy': {u'xlarge': u'images/2013/07/07/fashion/07JPCAMP3/JPCAMP3-articleLarge.jpg',
#       u'xlargeheight': u'901',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/fashion/07JPCAMP3/JPCAMP3-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2013/07/07/fashion/07COVER_SPAN/07COVER-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/fashion/07COVER_SPAN/07COVER-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'Styles',
#    u'print_page': u'1',
#    u'pub_date': u'2013-07-07T00:00:00Z',
#    u'section_name': u'Fashion & Style',
#    u'snippet': u'In the woods, tech-addled adults can break the bonds of the digital world, at least temporarily,  and return to the glories of color wars and real (not Facebook) friends.',
#    u'source': u'The New York Times',
#    u'subsection_name': None,
#    u'type_of_material': u'News',
#    u'web_url': u'http://www.nytimes.com/2013/07/07/fashion/a-trip-to-camp-to-break-a-tech-addiction.html',
#    u'word_count': u'2031'},
#   {u'_id': u'51d72b0a7e0d9c0839d2e37b',
#    u'abstract': None,
#    u'blog': [],
#    u'byline': {u'contributor': u'',
#     u'original': u'By LEO LEVINE',
#     u'person': [{u'firstname': u'Leo',
#       u'lastname': u'LEVINE',
#       u'organization': u'',
#       u'rank': 1,
#       u'role': u'reported'}]},
#    u'document_type': u'article',
#    u'headline': {u'kicker': u'Auctions',
#     u'main': u'A Singular Mercedes Aims for Another Record',
#     u'print_headline': u'A Singular Mercedes Aims for Another Record'},
#    u'keywords': [{u'is_major': u'N',
#      u'name': u'organizations',
#      u'rank': u'3',
#      u'value': u'Mercedes-Benz'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'1',
#      u'value': u'Automobiles'},
#     {u'is_major': u'N',
#      u'name': u'subject',
#      u'rank': u'2',
#      u'value': u'Antique and Classic Cars'},
#     {u'is_major': u'N',
#      u'name': u'glocations',
#      u'rank': u'4',
#      u'value': u'Great Britain'}],
#    u'lead_paragraph': u'A 1954 Mercedes-Benz W196 grand prix car raced by the world champion Juan Manuel Fangio of Argentina will be auctioned on Friday in Britain and could set a record for an automobile sold at auction.',
#    u'multimedia': [{u'height': 126,
#      u'legacy': {u'wide': u'images/2013/07/07/automobiles/Fangio1/Fangio1-thumbWide.jpg',
#       u'wideheight': u'126',
#       u'widewidth': u'190'},
#      u'subtype': u'wide',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/automobiles/Fangio1/Fangio1-thumbWide.jpg',
#      u'width': 190},
#     {u'height': 208,
#      u'legacy': {u'xlarge': u'images/2013/07/07/automobiles/Fangio1/Fangio1-articleLarge.jpg',
#       u'xlargeheight': u'208',
#       u'xlargewidth': u'600'},
#      u'subtype': u'xlarge',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/automobiles/Fangio1/Fangio1-articleLarge.jpg',
#      u'width': 600},
#     {u'height': 75,
#      u'legacy': {u'thumbnail': u'images/2013/07/07/automobiles/Fangio1/Fangio1-thumbStandard.jpg',
#       u'thumbnailheight': u'75',
#       u'thumbnailwidth': u'75'},
#      u'subtype': u'thumbnail',
#      u'type': u'image',
#      u'url': u'images/2013/07/07/automobiles/Fangio1/Fangio1-thumbStandard.jpg',
#      u'width': 75}],
#    u'news_desk': u'Automobiles',
#    u'print_page': u'7',
#    u'pub_date': u'2013-07-07T00:00:00Z',
#    u'section_name': u'Automobiles',
#    u'snippet': u'A 1954 Mercedes-Benz W196 grand prix car raced by the world champion Juan Manuel Fangio of Argentina will be auctioned on Friday in Britain and could set a record for an automobile sold at auction.',
#    u'source': u'The New York Times',
#    u'subsection_name': None,
#    u'type_of_material': u'News',
#    u'web_url': u'http://www.nytimes.com/2013/07/07/automobiles/a-singular-mercedes-aims-for-another-record.html',
#    u'word_count': u'605'}],
#  u'meta': {u'hits': 127665, u'offset': 0, u'time': 172}}

# %%
res
# Out:
# [{u'date': datetime.datetime(2007, 12, 20, 0, 0),
#   u'title': u'In His Charity and Her Politics, Many Clinton Donors Overlap'},
#  {u'date': datetime.datetime(2007, 12, 4, 0, 0),
#   u'title': u'EDITORIAL OBSERVER; Congress Has a Way of Making Witnesses Speak: Its Own Jail'},
#  {u'date': datetime.datetime(2007, 11, 19, 0, 0),
#   u'title': u'EDITORIAL; Reform and Consumer Safety'},
#  {u'date': datetime.datetime(2007, 10, 30, 0, 0),
#   u'title': u'EDITORIAL OBSERVER; Honey, They Shrunk the Congress'},
#  {u'date': datetime.datetime(2007, 10, 17, 0, 0),
#   u'title': u'THE TV WATCH; Humiliation, if Not Candor, From Senator on the Defensive'},
#  {u'date': datetime.datetime(2007, 10, 16, 0, 0),
#   u'title': u'Scrutinized U.S. Official Dies in Apparent Suicide'},
#  {u'date': datetime.datetime(2007, 10, 15, 0, 0),
#   u'title': u'Tribe Proposes a Casino For a Queens Racetrack'},
#  {u'date': datetime.datetime(2007, 10, 7, 0, 0),
#   u'title': u'EDITORIAL; The Mystery of the Coconut Interchange'},
#  {u'date': datetime.datetime(2007, 10, 5, 0, 0),
#   u'title': u"Guilty Plea Stands, but Craig Won't Quit Senate"},
#  {u'date': datetime.datetime(2007, 9, 28, 0, 0),
#   u'title': u'For Craig and Others, a Caucus on the Potomac'}]

# %% [markdown]
# ##Scrape Text

# %% [markdown]
# Here are a few of the resulting URLS that we'll use to get the full text articles:

# %%
[doc['url'] for doc in db.raw_text.find()][:5]
# Out:
# [u'http://www.nytimes.com/2007/08/15/opinion/15wed3.html',
#  u'http://www.nytimes.com/2007/03/16/washington/16cong.html',
#  u'http://www.nytimes.com/2006/03/11/politics/11lobby.html',
#  u'http://www.nytimes.com/2006/04/30/washington/30cunningham.html',
#  u'http://www.nytimes.com/2004/04/09/business/senate-panel-asked-to-give-sec-proposals-a-chance.html']

# %% [markdown]
# The scraping wasn't as difficult as I was expecting; over the 20 or so years that I searched for, the body text of the articles could be found by looking at 5 html elements (formatted as CSS selectors in `_sels` below). The following two functions do most of the scraping work-- `get_text`...well...gets the text from the `CSSSelector` parser, and the `grab_text` uses this after pulling the html with requests again.

# %%
def get_text(e):
    "Function to extract text from CSSSelector results"
    try:
        return ' '.join(e.itertext()).strip().encode('ascii', 'ignore')
    except UnicodeDecodeError:
        return ''


def grab_text(url, verbose=True):
    "Main scraping function--given url, grabs html, looks for and returns article text"
    if verbose:  #page counter
        print grab_text.c,
    grab_text.c += 1
    r = requests.get(url, params=all_pages)
    content = fromstring(r.content)
    for _sel in _sels:
        text_elems = CSSSelector(_sel)(content)
        if text_elems:
            return '\n'.join(map(get_text, text_elems))
    return ''

#Selectors where text of articles can be found; quite a few patterns among NYT articles
_sels =  ['p[itemprop="articleBody"]', "div.blurb-text", 'div#articleBody p', 'div.articleBody p', 'div.mod-nytimesarticletext p']
all_pages = {'pagewanted': 'all'}

# %% [markdown]
# And here is the main loop and counter. Pretty simple, huh?
#
# On the first run, the output counts up from zero, but since political scandals seem to be popping up by the hour, I've updated the search a few times, but only pulling articles that aren't already in the database (hence the mostly underscored output below).

# %%
grab_text.c = 0
for doc in db.raw_text.find():
    if ('url' in doc) and ('text' not in doc):
        # if we don't already have this in mongodb
        txt = grab_text(doc['url'])
        db.raw_text.update({'url': doc['url']}, {'$set': {'text': txt}})
    else:
        print '_',

db.raw_text.remove({'text': u''})  #there was one weird result that didn't have any text...
# Out:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#  _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _

# %% [markdown]
# And, we got more than 870 scandalous stories...but still counting!

# %%
len(list(db.raw_text.find()))
# Out:
# 874

# %% [markdown]
# ###Conclusion
# Though it turned out to be pretty brief, I thought this first part of my NYT scandals project deserved its own post.
# Luckily it doesn't take too much effort or space when you're working with a nice, expressive language, though.
# And you can reproduce this for yourself--you can find a copy of this notebook on github.
